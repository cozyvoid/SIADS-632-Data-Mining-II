# %% [markdown]
# # Tasks of Time Series Data Mining
#
# ---

# %% [markdown]
# ### Output of mining time series data
#
# - Visualization
# - Pattern discovery
# - Similarity
# - Modeling
# - Prediction/forecasting
# - Anomaly detection
# - Classification
# - Clustering
# - ...

# %% [markdown]
# ### Patterns in Time Series
#
# - Trend, or (trend curve): long-term movements:
# - Cyclic movements: long term oscillations about a trend line or curve
# - Seasonal movements: periodic patterns
# - Irregular movements: anomaly, outlier, randomness...

# %% [markdown]
# ### Trends, cycles, outliers
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Seasonal patterns
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Time series similarity
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series modeling
#
# - Usually by learning a function
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series forecasting
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Anamoly detection
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series classification
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series clustering
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Applications of time series analysis
#
# - Finance
# - Healthcare
# - Business intelligence
# - Sports
# - Meteorology
# - Education
# - Sciences: results analysis
# - Engineering: signal processing
# - ...

# %% [markdown]
# ### What you should know
#
# - How a time series is different from a sequence and a vector
# - The difference and connection between discrete representation and continuous representation
