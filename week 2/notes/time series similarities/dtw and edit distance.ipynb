# %% [markdown]
# # DTW and Edit Distance
#
# ---

# %% [markdown]
# ### Connection
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### DTW and Edit Distance
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Implementation details
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series "edit distances"
#
# - Time warp edit distance
# - Longest common subsequences
