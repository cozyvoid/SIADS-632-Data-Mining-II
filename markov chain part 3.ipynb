# %% [markdown]
# # Markov Chain
# ## Part 3
#
# ---

# %% [markdown]
# ### Estimating the probabilities
#
# - To use a Markov Chain, we need to find:
#     - Initial probabilities: each word as the first word in a sequenceL $P(w_i)$
#     - For complete sequences, consider <S> as a word, and P(<S>) = 1
#     - For partial sequences:
#
# ![image.png](attachment:image.png)
#
#     - Transition probabilities: each word depending on a previous word: $P(w_j | w_i)$
#         - For complete sequences, consider end of sequence <E> as a word
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Independence assumptions
#
# ![image.png](attachment:image.png)
