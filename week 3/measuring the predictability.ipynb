# %% [markdown]
# # Measuring the Predictability
#
# ---

# %% [markdown]
# ### Goodness of fit
#
# - For every $t_i$ in a time series, we have a predicted value $\hat y_i$
# - $y_i$ is the value we actually observed
# - $y_i - \hat y_i$ is called the residual (observed error)
# - Residual Sum of Squares ($RSS$ or $SS_{RES}$)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Root Mean Square Error (RMSE)
#
# - Expectation of square error, then take the square root
# - Interpretable (comparable to *y*)
# - Usually computed based on hold-on test samples
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### R-squared
#
# - RSS and RMSE are comparable on the same time series!
# - Comparing RSS and RSME for different prediction targets can be misleading (because one target can be intrinsically harder to predict)
# - $R^2$ (R-Squared): explained variance / total variance
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### More on R-squared
#
# - R-squared is between 0 and 1
# - Good to describe the general predictive power of the model
# - But hard to interpret the practical value of prediction
# - Doesn't describe the predictive power of individual features

# %% [markdown]
# ### Autocorrection
#
# - Autocorrection of a time series computes correlation over different lags: $y_t$ and $y_{t-k}$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Autocorrection function (ACF) plot
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ACF of the airline passenger series
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ACF of the white noise series
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Partial autocorrection function plot
#
# - If $y_{t-1}$ is correlated with $y_t$, then $y_{t-2}$ is likely too (because it is correlated with $y_{t-2})$
# - Partial autocorrelation: remove the effect of a correlation with a longer lag (e.g., $y_{t-1})$ due to the observations with shorter lags (e.g., $y_{t-i+1}... y_{t-1}$)

# %% [markdown]
# ### PACF plot
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What does autocorrelation tell us?
#
# - $y_{t-i}$ may have a prediction power for $y_t$
# - We may build a prediction model that uses $y_{t-i}$ to predict $y_t$
# - There are multiple $y_{t-i}$ (with different *i*) that are more or less predictive
# - Does this remind you of n-gram language models?
# - Both $y_t$ and $y_{t-i}$ are numerical, so we need to use regression
