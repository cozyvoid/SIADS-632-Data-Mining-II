# %% [markdown]
# # Vector autoregressions
#
# ---

# %% [markdown]
# ### Prediction of multivariate series
#
# - In many cases we have multiple aligned time series
# - Measurements of different variables
# - We want to use one to make prediction for another

# %% [markdown]
# ### Example
#
# - GDP
# - Expenditures
# - Domestic Investment
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Vector autoregression (VAR)
#
# - Input: multuple aligned time series (multi-dimensional series)
# - Predict the future observation of one series using the past observations of all series
# - Example: two series X, Y, VAR(p)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Examples of VAR (ACF)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Extending VAR
#
# - Easily generalizable to *K* dimensions
# - Same idea also applies to MA, ARMA, ARIMA
# - VMA
# - VARMA
# - VARIMA
