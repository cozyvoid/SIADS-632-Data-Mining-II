# %% [markdown]
# # Data Streams
#
# ---

# %% [markdown]
# ### Sequence data
#
# - An ordered list of categorical items:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series data
#
# - A list of timestamped values (measurements):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Data Streams
#
# - A list of ordered or timestamped **data objects, or "events"**
# - Every event can be either a simple (e.g., an item) data object or a complex one (e.g., a mixture of itemsets, vectors, sequences, etc.)
#
# - Continuous arrival of events into the future
#
# ![image.png](attachment:image.png)
#
# - The entire history is usually too long to store.

# %% [markdown]
# ### Data streams in the real world
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Functionalities of stream data mining
#
# - patterns
# - similarity
# - modeling
# - prediction
# - forecasting
# - classification
# - clustering
# - outlier detection
# - ...
#
# - None of these outputs look very different from sequence data or time series
# - What are the special challenges for mining data streams?

# %% [markdown]
# ### Challenges of mining stream data
#
# - One example question that summarizes all the challenges:
#     - 500 million Tweets being generated per day
#     - You have the capacity to keep 1000 tweets (at a given time)
#     - How do you do data mining?

# %% [markdown]
# ### Constraints of mining stream data
#
# - Usually cannot store the entire history (or even part of it)
# - Usually cannot look back
# - Have to deal with events "in order"
# - Have to do everything "online"

# %% [markdown]
# ### Application: information filtering
#
# - facebook
# - twitter
# - news feed
# - amazon
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Application: fraud detection
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What you should know
#
# - How data stream is different from sequence and time series
# - Real world examples and applications of data streams
# - Special challenges of mining data streams
